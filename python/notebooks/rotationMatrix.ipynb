# %%
# %pylab inline
import sympy as sp
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
π = pi
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /home/pl/miniconda3/lib/python3.12/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['interactive']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
nPoints = 5
x_o = random.random(nPoints)-0.5
y_o = random.random(nPoints)-0.5

scatter(x_o,y_o)
xlim([-1,1])
ylim([-1,1])
axhline()
axvline()

# %%
deg = 20
θ = 2*π*deg/360 
A = array([[cos(θ), -sin(θ)],
           [sin(θ), cos(θ)]])
#check for orthogonality:
A.T@A
# Out:
# array([[ 1.00000000e+00, -2.22218033e-17],
#        [-2.22218033e-17,  1.00000000e+00]])

# %%
X = array([x,y])

# %%
Y = A@X

# %%
# Out:
# array([[1.00000000e+00, 2.22218033e-17],
#        [2.22218033e-17, 1.00000000e+00]])

# %%
figure(figsize=[6,6])
scatter(*X)
scatter(*Y, c='r')

plot(*X)
plot(*Y, 'r--')

xlim([-1,1])
ylim([-1,1])
axhline(lw=0.5)
axvline(lw=0.5)

# plt.savefig("../plots/rotMat.pgf", bbox_inches='tight')

# %%
def plotRot(deg):

    θ = 2*π*deg/360 
    A = array([[cos(θ), -sin(θ)],
               [sin(θ), cos(θ)]])

    Y = A@X
    
    figure(figsize=[5,5])
    # plot(Zx, Zy)
    scatter(*X)
    plot(*X)
    scatter(*Y, c='r')
    plot(*Y, 'r--')
    xlim([-1,1])
    ylim([-1,1])
    axhline(lw=0.5)
    axvline(lw=0.5)
    show()

interact(plotRot, deg=widgets.FloatSlider(min=-360, max=360, step=0.1, value=0))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='deg', max=360.0, min=-360.0), Output()), _dom_classe…
# <function __main__.plotRot(deg)>
